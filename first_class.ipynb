# %%
from stats.gaussian import Gaussian

# %%
gs = Gaussian()
gs.read_data_file("data_file.txt")

# %%
gs.plot_histogram()

# %%
gs_a = Gaussian(10,1)
gs_b = Gaussian(5,2)

gs_sum = gs_a + gs_b

# %%
gs_sum
# Out:
# mean 15, standard deviation 2.23606797749979

# %%
gs_sum.mean
# Out:
# 15
